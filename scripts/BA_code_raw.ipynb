# %%
import pandas as pd
import os
import glob # immprt many many files .csv
from tqdm import tqdm # progress bar

# %% [markdown]
# # Inserting the Data

# %%
# first we need to change the working directory because glob only takes the current wd
path_main = 'C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/' # please change the directory to where you want to have it
os.chdir(path_main)

dictionary_main = {}

for file in os.listdir(path_main):
    # print(file)
    df_main = pd.read_csv(file) 
    dictionary_main[file.rstrip('.csv')] = df_main #für den key "file name" mache einen eintag und wenn er noch nicht existert erstelle ihn als wert
    
#print(dictionary)
dictionary_main['VP03_Main']
# Out:
#     Explaination_key_resp.keys  Explaination_key_resp.rt  \
# 0                        space                   26.7442
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 131                        NaN                       NaN
# 132                        NaN                       NaN
# 133                        NaN                       NaN
# 134                        NaN                       NaN
# 135                        NaN                       NaN
#
#     Explaination2_key_resp.keys  Explaination2_key_resp.rt  \
# 0                         space                    21.6781
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# ...

# %%
#first lets grab a path and change to it
path_post = 'C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/'
os.chdir(path_post)

# make variable that aint a variable innit 
dictionary_post = {}

#write the for look
for file in os.listdir(path_post):
    df_post = pd.read_csv(file)
    dictionary_post[file.rstrip('.csv')] = df_post

#check if it wolks
dictionary_post['VP01_Post']
# Out:
#     key_resp_Intro2.keys  key_resp_Intro2.rt key_resp_Intro3.keys  \
# 0                  space               22.58                space
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# ..                   ...                 ...                  ...
# 141                  NaN                 NaN                  NaN
# 142                  NaN                 NaN                  NaN
# 143                  NaN                 NaN                  NaN
# 144                  NaN                 NaN                  NaN
# 145                  NaN                 NaN                  NaN
#
#      key_resp_Intro3.rt  slider_Buffer.response  slider_Buffer.rt  \
# 0                30.976                     5.0             6.826
# ...

# %%
VP01_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP01_Main.csv')
VP02_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP02_Main.csv')
VP03_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP03_Main.csv')
VP04_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP04_Main.csv')
VP05_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP05_Main.csv')
VP06_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP06_Main.csv')
VP07_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP07_Main.csv')
VP08_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP08_Main.csv')
VP09_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP09_Main.csv')
VP11_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP11_Main.csv')
VP12_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP12_Main.csv')
VP14_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP14_Main.csv')
VP17_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP17_Main.csv')
VP18_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP18_Main.csv')
VP19_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP19_Main.csv')
VP21_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP21_Main.csv')
VP22_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP22_Main.csv')
VP23_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP23_Main.csv')
VP28_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP28_Main.csv')
VP30_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP30_Main.csv')
VP31_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP31_Main.csv')
VP32_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP32_Main.csv')
VP33_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP33_Main.csv')
VP34_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP34_Main.csv')
VP36_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP36_Main.csv')
VP37_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP37_Main.csv')
VP38_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP38_Main.csv')
VP40_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP40_Main.csv')
VP41_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP41_Main.csv')
VP42_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP42_Main.csv')
VP45_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP45_Main.csv')
VP47_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP47_Main.csv')
VP49_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP49_Main.csv')
VP51_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP51_Main.csv')
VP52_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP52_Main.csv')
VP53_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP53_Main.csv')
VP54_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP54_Main.csv')
VP56_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP56_Main.csv')
VP60_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP60_Main.csv')
VP64_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP64_Main.csv')
VP65_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP65_Main.csv')
VP66_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP66_Main.csv')
VP70_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP70_Main.csv')
VP71_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP71_Main.csv')
VP73_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP73_Main.csv')
VP74_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP74_Main.csv')
VP75_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP75_Main.csv')
VP77_Main = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/02_Main_Study/data/VP77_Main.csv')

# %%
VP01_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP01_Post.csv')
VP02_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP02_Post.csv')
VP03_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP03_Post.csv')
VP04_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP04_Post.csv')
VP05_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP05_Post.csv')
VP06_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP06_Post.csv')
VP07_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP07_Post.csv')
VP08_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP08_Post.csv')
VP09_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP09_Post.csv')
VP11_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP11_Post.csv')
VP12_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP12_Post.csv')
VP14_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP14_Post.csv')
VP17_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP17_Post.csv')
VP18_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP18_Post.csv')
VP19_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP19_Post.csv')
VP21_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP21_Post.csv')
VP22_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP22_Post.csv')
VP23_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP23_Post.csv')
VP28_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP28_Post.csv')
VP30_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP30_Post.csv')
VP31_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP31_Post.csv')
VP32_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP32_Post.csv')
VP33_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP33_Post.csv')
VP34_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP34_Post.csv')
VP36_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP36_Post.csv')
VP37_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP37_Post.csv')
VP38_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP38_Post.csv')
VP40_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP40_Post.csv')
VP41_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP41_Post.csv')
VP42_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP42_Post.csv')
VP45_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP45_Post.csv')
VP47_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP47_Post.csv')
VP49_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP49_Post.csv')
VP51_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP51_Post.csv')
VP52_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP52_Post.csv')
VP53_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP53_Post.csv')
VP54_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP54_Post.csv')
VP56_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP56_Post.csv')
VP60_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP60_Post.csv')
VP64_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP64_Post.csv')
VP65_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP65_Post.csv')
VP66_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP66_Post.csv')
VP70_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP70_Post.csv')
VP71_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP71_Post.csv')
VP73_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP73_Post.csv')
VP74_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP74_Post.csv')
VP75_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP75_Post.csv')
VP77_Post = pd.read_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/03_Post_Study/data/VP77_Post.csv')

# %% [markdown]
# ## Rename Post-Hoc_Item to Item
# see at the top in line 3 there should be 'Post_Hoc_Item' and in the lower code this will have changed to 'Item' for all values in the dictionary

# %%
    print(dictionary_post['VP01_Post'].columns.values.tolist())
# Out:
# ['key_resp_Intro2.keys', 'key_resp_Intro2.rt', 'key_resp_Intro3.keys', 'key_resp_Intro3.rt', 'slider_Buffer.response', 'slider_Buffer.rt', 'trials_Warm_Up.thisRepN', 'trials_Warm_Up.thisTrialN', 'trials_Warm_Up.thisN', 'trials_Warm_Up.thisIndex', 'trials_Warm_Up.ran', 'Post_Hoc_ID', 'Post_Hoc_Item', 'participant', 'Vorname', 'Nachname', 'Mit welchem Geschlecht identifiziert du dich? (m,w,nicht-binär,keine Angabe)', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'key_resp_Intro4.keys', 'key_resp_Intro4.rt', 'slider_Trial.response', 'slider_Trial.rt', 'trials.thisRepN', 'trials.thisTrialN', 'trials.thisN', 'trials.thisIndex', 'trials.ran', 'Norming_Rating_Median', 'Norming_Item_Class', 'key_resp.keys', 'key_resp.rt', 'trials_2.thisRepN', 'trials_2.thisTrialN', 'trials_2.thisN', 'trials_2.thisIndex', 'trials_2.ran']

# %%
for key in dictionary_post.keys():
#     print(key)
    df_to_rename = dictionary_post[key]

    df_post = df_to_rename.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
    
    print(dictionary_post[key].columns.values.tolist())
# Out:
# ['key_resp_Intro2.keys', 'key_resp_Intro2.rt', 'key_resp_Intro3.keys', 'key_resp_Intro3.rt', 'slider_Buffer.response', 'slider_Buffer.rt', 'trials_Warm_Up.thisRepN', 'trials_Warm_Up.thisTrialN', 'trials_Warm_Up.thisN', 'trials_Warm_Up.thisIndex', 'trials_Warm_Up.ran', 'Post_Hoc_ID', 'Item', 'participant', 'Vorname', 'Nachname', 'Mit welchem Geschlecht identifiziert du dich? (m,w,nicht-binär,keine Angabe)', 'date', 'expName', 'psychopyVersion', 'OS', 'frameRate', 'key_resp_Intro4.keys', 'key_resp_Intro4.rt', 'slider_Trial.response', 'slider_Trial.rt', 'trials.thisRepN', 'trials.thisTrialN', 'trials.thisN', 'trials.thisIndex', 'trials.ran', 'Norming_Rating_Median', 'Norming_Item_Class', 'key_resp.keys', 'key_resp.rt', 'trials_2.thisRepN', 'trials_2.thisTrialN', 'trials_2.thisN', 'trials_2.thisIndex', 'trials_2.ran']
# ...

# %%
VP01_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP02_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP03_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP04_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP05_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP06_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP07_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP08_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP09_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP11_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP12_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP14_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP17_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP18_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP19_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP21_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP22_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP23_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP28_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP30_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP31_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP32_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP33_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP34_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP36_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP37_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP38_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP40_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP41_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP42_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP45_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP47_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP49_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP51_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP52_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP53_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP54_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP56_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP60_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP64_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP65_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP66_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP70_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP71_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP73_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP74_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP75_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
VP77_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 VP01_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
#       2 VP02_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
#       3 VP03_Post.rename(columns={'Post_Hoc_Item':'Item'}, inplace = True)
#
# NameError: name 'VP01_Post' is not defined

# %% [markdown]
# # Merging Main and Post and Save as csv
# https://www.youtube.com/watch?v=iYWKfUOtGaw&

# %%
#the path will be useful for when we want to save the dfs
path = 'C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/'

for key in dictionary_post.keys():
#     print(key)
    df_to_merge = dictionary_post[key]

    key = key.rstrip('_Post')
    key = key + '_Main' 

    df_the_base = dictionary_main[key]
    
#
    df_merged = pd.merge(df_the_base, df_to_merge, on='Item', how='left')
#     print(key)
    
    
#--------------------------------------------------------------------------------------
#saving the df
    key_bare = key.rstrip('_Main')
    print(key_bare)
    df_merged.to_csv(path + key_bare + '.csv')
# Out:
# VP01
# VP02
# VP03
# VP04
# VP05
# VP06
# VP07
# VP08
# VP09
# VP11
# VP12
# VP14
# VP17
# VP18
# VP19
# VP21
# VP22
# VP23
# VP27
# VP28
# VP29
# VP30
# VP31
# VP32
# VP33
# VP34
# VP35
# VP36
# VP37
# VP38
# VP40
# VP41
# VP42
# VP45
# VP47
# VP49
# VP51
# VP52
# VP53
# VP54
# VP56
# VP60
# VP61
# VP64
# VP65
# VP66
# VP68
# VP69
# VP70
# VP71
# VP73
# VP74
# VP75
# VP77

# %%
VP01 = pd.merge(VP01_Main, VP01_Post, on='Item', how='left')
VP02 = pd.merge(VP02_Main, VP02_Post, on='Item', how='left')
VP03 = pd.merge(VP03_Main, VP03_Post, on='Item', how='left')
VP04 = pd.merge(VP04_Main, VP04_Post, on='Item', how='left')
VP05 = pd.merge(VP05_Main, VP05_Post, on='Item', how='left')
VP06 = pd.merge(VP06_Main, VP06_Post, on='Item', how='left')
VP07 = pd.merge(VP07_Main, VP07_Post, on='Item', how='left')
VP08 = pd.merge(VP08_Main, VP08_Post, on='Item', how='left')
VP09 = pd.merge(VP09_Main, VP09_Post, on='Item', how='left')
VP11 = pd.merge(VP11_Main, VP11_Post, on='Item', how='left')
VP12 = pd.merge(VP12_Main, VP12_Post, on='Item', how='left')
VP14 = pd.merge(VP14_Main, VP14_Post, on='Item', how='left')
VP17 = pd.merge(VP17_Main, VP17_Post, on='Item', how='left')
VP18 = pd.merge(VP18_Main, VP18_Post, on='Item', how='left')
VP19 = pd.merge(VP19_Main, VP19_Post, on='Item', how='left')
VP21 = pd.merge(VP21_Main, VP21_Post, on='Item', how='left')
VP22 = pd.merge(VP22_Main, VP22_Post, on='Item', how='left')
VP23 = pd.merge(VP23_Main, VP23_Post, on='Item', how='left')
VP28 = pd.merge(VP28_Main, VP28_Post, on='Item', how='left')
VP30 = pd.merge(VP30_Main, VP30_Post, on='Item', how='left')
VP31 = pd.merge(VP31_Main, VP31_Post, on='Item', how='left')
VP32 = pd.merge(VP32_Main, VP32_Post, on='Item', how='left')
VP33 = pd.merge(VP33_Main, VP33_Post, on='Item', how='left')
VP34 = pd.merge(VP34_Main, VP34_Post, on='Item', how='left')
VP36 = pd.merge(VP36_Main, VP36_Post, on='Item', how='left')
VP37 = pd.merge(VP37_Main, VP37_Post, on='Item', how='left')
VP38 = pd.merge(VP38_Main, VP38_Post, on='Item', how='left')
VP40 = pd.merge(VP40_Main, VP40_Post, on='Item', how='left')
VP41 = pd.merge(VP41_Main, VP41_Post, on='Item', how='left')
VP42 = pd.merge(VP42_Main, VP42_Post, on='Item', how='left')
VP45 = pd.merge(VP45_Main, VP45_Post, on='Item', how='left')
VP47 = pd.merge(VP47_Main, VP47_Post, on='Item', how='left')
VP49 = pd.merge(VP49_Main, VP49_Post, on='Item', how='left')
VP51 = pd.merge(VP51_Main, VP51_Post, on='Item', how='left')
VP52 = pd.merge(VP52_Main, VP52_Post, on='Item', how='left')
VP53 = pd.merge(VP53_Main, VP53_Post, on='Item', how='left')
VP54 = pd.merge(VP54_Main, VP54_Post, on='Item', how='left')
VP56 = pd.merge(VP56_Main, VP56_Post, on='Item', how='left')
VP60 = pd.merge(VP60_Main, VP60_Post, on='Item', how='left')
VP64 = pd.merge(VP64_Main, VP64_Post, on='Item', how='left')
VP65 = pd.merge(VP65_Main, VP65_Post, on='Item', how='left')
VP66 = pd.merge(VP66_Main, VP66_Post, on='Item', how='left')
VP70 = pd.merge(VP70_Main, VP70_Post, on='Item', how='left')
VP71 = pd.merge(VP71_Main, VP71_Post, on='Item', how='left')
VP73 = pd.merge(VP73_Main, VP73_Post, on='Item', how='left')
VP74 = pd.merge(VP74_Main, VP74_Post, on='Item', how='left')
VP75 = pd.merge(VP75_Main, VP75_Post, on='Item', how='left')
VP77 = pd.merge(VP77_Main, VP77_Post, on='Item', how='left')

# %% [markdown]
# ## Save the data

# %%
VP01.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP01.csv')
VP02.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP02.csv')
VP03.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP03.csv')
VP04.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP04.csv')
VP05.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP05.csv')
VP06.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP06.csv')
VP07.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP07.csv')
VP08.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP08.csv')
VP09.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP09.csv')
VP11.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP11.csv')
VP12.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP12.csv')
VP14.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP14.csv')
VP17.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP17.csv')
VP18.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP18.csv')
VP19.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP19.csv')
VP21.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP21.csv')
VP22.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP22.csv')
VP23.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP23.csv')
VP28.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP28.csv')
VP30.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP30.csv')
VP31.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP31.csv')
VP32.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP32.csv')
VP33.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP33.csv')
VP34.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP34.csv')
VP36.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP36.csv')
VP37.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP37.csv')
VP38.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP38.csv')
VP40.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP40.csv')
VP41.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP41.csv')
VP42.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP42.csv')
VP45.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP45.csv')
VP47.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP47.csv')
VP49.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP49.csv')
VP51.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP51.csv')
VP52.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP52.csv')
VP53.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP53.csv')
VP54.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP54.csv')
VP56.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP56.csv')
VP60.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP60.csv')
VP64.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP64.csv')
VP65.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP65.csv')
VP66.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP66.csv')
VP70.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP70.csv')
VP71.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP71.csv')
VP73.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP73.csv')
VP74.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP74.csv')
VP75.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP75.csv')
VP77.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP77.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 VP01.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP01.csv')
#       2 VP02.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP02.csv')
#       3 VP03.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/VP03.csv')
#
# NameError: name 'VP01' is not defined

# %% [markdown]
# # Merging to one df
# below you will find the code that apends all VP dfs

# %%
# first we need to change the working directory because glob only takes the current wd
path = 'C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/' # please change the directory to where you want to have it
os.chdir(path)

files = glob.glob('VP*')
df = pd.concat( (pd.read_csv(file) for file in files), ignore_index=True)
print(df)

# save a raw version of the df
df.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/df_raw.csv')
# Out:
#       Unnamed: 0 Explaination_key_resp.keys  Explaination_key_resp.rt  \
# 0              0                      space                    40.709
# 1              1                        NaN                       NaN
# 2              2                        NaN                       NaN
# 3              3                        NaN                       NaN
# 4              4                        NaN                       NaN
# ...          ...                        ...                       ...
# 7267         131                        NaN                       NaN
# 7268         132                        NaN                       NaN
# 7269         133                        NaN                       NaN
# 7270         134                        NaN                       NaN
# 7271         135                        NaN                       NaN
#
#      Explaination2_key_resp.keys  Explaination2_key_resp.rt  \
# 0                          space                     32.739
# ...

# %%
# first we need to change the working directory because glob only takes the current wd
path_main = 'C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/' # please change the directory to where you want to have it
os.chdir(path_main)

files = glob.glob('VP*')
#print(files)

for file in files:
    print(file)
# Out:
# VP01.csv
# VP02.csv
# VP03.csv
# VP04.csv
# VP05.csv
# VP06.csv
# VP07.csv
# VP08.csv
# VP09.csv
# VP11.csv
# VP12.csv
# VP14.csv
# VP17.csv
# VP18.csv
# VP19.csv
# VP21.csv
# VP22.csv
# VP23.csv
# VP28.csv
# VP30.csv
# VP31.csv
# VP32.csv
# VP33.csv
# VP34.csv
# VP36.csv
# VP37.csv
# VP38.csv
# VP40.csv
# VP41.csv
# VP42.csv
# VP45.csv
# VP47.csv
# VP49.csv
# VP51.csv
# VP52.csv
# VP53.csv
# VP54.csv
# VP56.csv
# VP60.csv
# VP64.csv
# VP65.csv
# VP66.csv
# VP70.csv
# VP71.csv
# VP73.csv
# VP74.csv
# VP75.csv
# VP77.csv

# %% [markdown]
# ## View Columns

# %%
df.columns.values.tolist() #this comand lists all columns
# Out:
# ['Unnamed: 0',
#  'Explaination_key_resp.keys',
#  'Explaination_key_resp.rt',
#  'Explaination2_key_resp.keys',
#  'Explaination2_key_resp.rt',
#  'Pos01_Name_key_resp.keys',
#  'Pos01_Name_key_resp.rt',
#  'Pos02_V_key_resp.keys',
#  'Pos02_V_key_resp.rt',
#  'Pos03_PP_key_resp.keys',
#  'Pos03_PP_key_resp.rt',
#  'Pos04_PRO_key_resp.keys',
#  'Pos04_PRO_key_resp.rt',
#  'Pos05_key_resp.keys',
#  'Pos05_key_resp.rt',
#  'Pos06_key_resp.keys',
#  'Pos06_key_resp.rt',
#  'Pos07_key_resp.keys',
#  'Pos07_key_resp.rt',
#  'Pos08_key_resp.keys',
#  'Pos08_key_resp.rt',
#  'Pos09_key_resp.keys',
#  'Pos09_key_resp.rt',
#  'Comp_q_key_resp.keys',
#  'Comp_q_key_resp.rt',
#  'Comp_resp_key_resp.keys',
#  'Comp_resp_key_resp.rt',
#  'trials00_Loop.thisRepN',
#  'trials00_Loop.thisTrialN',
#  'trials00_Loop.thisN',
#  'trials00_Loop.thisIndex',
#  'trials00_Loop.ran',
#  'Stimuli_ID',
#  'List',
#  'List_Ordered',
#  'List_Randomized',
#  'Block',
#  'Sent_ID',
#  'Sentence_full',
# ...

# %% [markdown]
# ## Delete columns (i)
# .drop('...')

# %%
df = df[df.columns.drop(list(df.filter(regex='Explaination*')))]
df = df[df.columns.drop(list(df.filter(regex='Pos01_Name_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos02_V_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos03_PP_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos04_PRO_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos05_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos06_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos07_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos08_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Pos09_key_resp.keys')))]
# df = df[df.columns.drop(list(df.filter(regex='*key_resp.keys')))] # das nutze ich nicht da *resp bei comprehension wichtig ist
df = df[df.columns.drop(list(df.filter(regex='Comp_q_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='Comp_q_key_resp.rt')))]
df = df[df.columns.drop(list(df.filter(regex='trials*')))]
df = df[df.columns.drop(list(df.filter(regex='.*_alt')))]
df = df[df.columns.drop(list(df.filter(regex='Wo')))]
df = df[df.columns.drop(list(df.filter(regex='Wohin')))]
df = df[df.columns.drop(list(df.filter(regex='Woher')))]
df = df[df.columns.drop(list(df.filter(regex='PP_*')))]
df = df[df.columns.drop(list(df.filter(regex='Was')))]
df = df[df.columns.drop(list(df.filter(regex='Wen')))]
df = df[df.columns.drop(list(df.filter(regex='Pos09_*')))]
df = df[df.columns.drop(list(df.filter(regex='DET_small')))]
df = df[df.columns.drop(list(df.filter(regex='Pro_m')))]
df = df[df.columns.drop(list(df.filter(regex='Pro_f')))]
df = df[df.columns.drop(list(df.filter(regex='Pro_Presentation')))]
df = df[df.columns.drop(list(df.filter(regex='Wer')))]
df = df[df.columns.drop(list(df.filter(regex='Wo_Wohin_Woher')))]
df = df[df.columns.drop(list(df.filter(regex='Wen_Was')))]
df = df[df.columns.drop(list(df.filter(regex='Quest_OneOutOfFour')))]
df = df[df.columns.drop(list(df.filter(regex='Quest_Copy')))]
df = df[df.columns.drop(list(df.filter(regex='Quest_Up')))]
df = df[df.columns.drop(list(df.filter(regex='Quest_Down')))]
df = df[df.columns.drop(list(df.filter(regex='Quest_Block*')))]
df = df[df.columns.drop(list(df.filter(regex='E-Mail-Adresse')))]
df = df[df.columns.drop(list(df.filter(regex='date*')))]
df = df[df.columns.drop(list(df.filter(regex='expName*')))]
df = df[df.columns.drop(list(df.filter(regex='psychopyVersion*')))]
df = df[df.columns.drop(list(df.filter(regex='OS*')))]
df = df[df.columns.drop(list(df.filter(regex='frameRate*')))]
df = df[df.columns.drop(list(df.filter(regex='Pause1_key_resp.keys')))]

#### now comes Post
# df = df[df.columns.drop(list(df.filter(regex='..._y')))]
df = df[df.columns.drop(list(df.filter(regex='slider_Buffer*')))]
df = df[df.columns.drop(list(df.filter(regex='key_resp_Intro*')))]
df = df[df.columns.drop(list(df.filter(regex='Comp_q_key_resp.rt')))]
df = df[df.columns.drop(list(df.filter(regex='Comp_q_key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='key_resp.keys')))]
df = df[df.columns.drop(list(df.filter(regex='key_resp.rt')))]

df.columns.values.tolist() #this comand lists all columns

# %% [markdown]
# ## Mergin columns that should be in one column
# there are sometimes two or more columns becaues there were breaks and

# %%
# df.columns.values.tolist() #this comand lists all columns

# l and Sentence_full

# print(df['trials_Loop.thisRepN'])
# df[['trials01_Loop.thisRepN', 'trials02_Loop.thisRepN']].agg(lambda x: ','.join(x.values), axis=1).T

# %% [markdown]
# ## Rename columns

# %%
# df.rename

# %% [markdown]
# Save File as csv

# %%
df.to_csv('C:/Users/alexa/Documents/02_study/duesseldorf/BA_Linguistik/09_BBA_Bachelorarbeit/02_daten/df.csv')
